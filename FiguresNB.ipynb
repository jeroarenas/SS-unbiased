# %%
from make_figures import make_figures

# %% [markdown]
# # 1. Simulations with white input

# %%
make_figures(M=64, N_max=140, n_runs=1000, w_norm=1.0, noise_power=0.1,
                 colouring="white", alignment="random", k=1,
                 marker_step=10, seed=42, show_title=True)
# Out:
# Sweeping N: 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.49N/s]

# %%
make_figures(M=64, N_max=240, n_runs=1000, w_norm=1.0, noise_power=0.5,
                 colouring="white", alignment="random", k=1,
                 marker_step=10, seed=42, show_title=True)
# Out:
# Sweeping N: 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:09<00:00,  1.86N/s]

# %% [markdown]
# # 2. Simulations with colored input (Section IV of the paper)

# %%
make_figures(M=64, N_max=160, n_runs=1000, w_norm=1.0, noise_power=0.1,
                 colouring=('ar1',0.9), alignment="random", k=1,
                 marker_step=10, seed=42, show_title=True)
# Out:
# Sweeping N: 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.33N/s]

# %%
make_figures(M=64, N_max=200, n_runs=1000, w_norm=1.0, noise_power=0.5,
                 colouring=('ar1',0.9), alignment="random", k=1,
                 marker_step=13, seed=42, show_title=True)
# Out:
# Sweeping N: 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:05<00:00,  2.06N/s]

# %% [markdown]
# # 3. Alignment with eigenvectors with smaller eigenvalues (Extra simulations)

# %%
make_figures(M=64, N_max=270, n_runs=1000, w_norm=1.0, noise_power=0.1,
                 colouring=('ar1',0.8), alignment="low", k=16,
                 marker_step=25, seed=42, show_title=True)
# Out:
# Sweeping N: 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.72N/s]
